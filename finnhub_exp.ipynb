# %%
import requests
import websocket
import datetime
import json
import numpy as np
import pandas as pd

# %%
api_key = 'bu6l53n48v6pfj0oklv0'
end = datetime.datetime(2020,9,1,0,0).strftime('%s')
start = datetime.datetime(2020,8,1,0,0).strftime('%s')
facebook = 'FB'
apple = 'AAPL'
amazon = 'AMZN'
netflix = 'NFLX'
google = 'GOOG'
companies = ['FB', 'AAPL', 'AMZN', 'NFLX', 'GOOG']

# %%
stock_quotes = pd.DataFrame()
for c in companies:
    r = requests.get('https://finnhub.io/api/v1/stock/candle?symbol=' + c + '&resolution=D&from=' + start+ '&to=' + end + '&token=bu6l53n48v6pfj0oklv0')
    y = json.loads(json.dumps(r.json()))
    t = [""]*len(y["t"])
    for x in range (0,len(t)):
        t[x] = datetime.datetime.fromtimestamp(y["t"][x]).strftime('20%y-%m-%d')
    company_quote = pd.DataFrame({
    'Company' : [c]*len(y["v"]),
    'Open' : np.round(y["o"]),
    'Close' : np.round(y["c"]),
    'Volume' : y["v"],
    'Date' : t
    })
    stock_quotes = pd.concat([stock_quotes, company_quote], axis = 0)

# %%
stock_quotes
# Out:
#    Company    Open   Close     Volume        Date
# 0       FB   253.0   252.0   23134104  2020-08-03
# 1       FB   252.0   250.0   17183532  2020-08-04
# 2       FB   250.0   249.0   13088361  2020-08-05
# 3       FB   249.0   265.0   45241612  2020-08-06
# 4       FB   264.0   268.0   72766368  2020-08-07
# 5       FB   268.0   263.0   30248826  2020-08-10
# 6       FB   261.0   256.0   28238284  2020-08-11
# 7       FB   259.0   260.0   21428328  2020-08-12
# 8       FB   261.0   261.0   17373970  2020-08-13
# 9       FB   262.0   261.0   14792708  2020-08-14
# 10      FB   262.0   261.0   13351062  2020-08-17
# 11      FB   261.0   262.0   18690384  2020-08-18
# 12      FB   261.0   263.0   23291464  2020-08-19
# 13      FB   262.0   269.0   20299688  2020-08-20
# 14      FB   269.0   267.0   15538615  2020-08-21
# 15      FB   271.0   271.0   23685604  2020-08-24
# 16      FB   272.0   281.0   42127240  2020-08-25
# 17      FB   285.0   304.0   69015152  2020-08-26
# 18      FB   300.0   293.0   30301308  2020-08-27
# 19      FB   295.0   294.0   17172416  2020-08-28
# 20      FB   294.0   293.0   17345134  2020-08-31
# 0     AAPL   108.0   109.0  308151392  2020-08-03
