# %%
import requests
import websocket
import datetime
import json
import numpy as np
import pandas as pd

# %%
api_key = 'bu6l53n48v6pfj0oklv0'
end = datetime.datetime(2020,9,1,0,0).strftime('%s')
start = datetime.datetime(2020,8,1,0,0).strftime('%s')
facebook = 'FB'
apple = 'AAPL'
amazon = 'AMZN'
netflix = 'NFLX'
google = 'GOOG'
companies = ['FB', 'AAPL', 'AMZN', 'NFLX', 'GOOG']

# %%
stock_quotes = pd.DataFrame()
for c in companies:
    r = requests.get('https://finnhub.io/api/v1/stock/candle?symbol=' + c + '&resolution=D&from=' + start+ '&to=' + end + '&token=bu6l53n48v6pfj0oklv0')
    y = json.loads(json.dumps(r.json()))
    t = [""]*len(y["t"])
    for x in range (0,len(t)):
        t[x] = datetime.datetime.fromtimestamp(y["t"][x]).strftime('%y-%m-%d')
    company_quote = pd.DataFrame({
    'Company' : [c]*len(y["v"]),
    'Open' : np.round(y["o"]),
    'Close' : np.round(y["c"]),
    'Volume' : y["v"],
    'Date' : t
    })
    stock_quotes = pd.concat([stock_quotes, company_quote], axis = 0).reset_index(drop=True)

# %%
stock_quotes
# Out:
#     Company    Open   Close     Volume      Date
# 0        FB   253.0   252.0   23134104  20-08-03
# 1        FB   252.0   250.0   17183532  20-08-04
# 2        FB   250.0   249.0   13088361  20-08-05
# 3        FB   249.0   265.0   45241612  20-08-06
# 4        FB   264.0   268.0   72766368  20-08-07
# 5        FB   268.0   263.0   30248826  20-08-10
# 6        FB   260.0   256.0   28238284  20-08-11
# 7        FB   259.0   260.0   21428328  20-08-12
# 8        FB   262.0   261.0   17373970  20-08-13
# 9        FB   262.0   261.0   14792708  20-08-14
# 10       FB   262.0   261.0   13351062  20-08-17
# 11       FB   261.0   262.0   18690384  20-08-18
# 12       FB   261.0   263.0   23291464  20-08-19
# 13       FB   262.0   269.0   20299688  20-08-20
# 14       FB   269.0   267.0   15538615  20-08-21
# 15       FB   271.0   271.0   23685604  20-08-24
# 16       FB   272.0   281.0   42127240  20-08-25
# 17       FB   284.0   304.0   69015152  20-08-26
# 18       FB   300.0   293.0   30301308  20-08-27
# 19       FB   295.0   294.0   17172416  20-08-28
# 20       FB   294.0   293.0   17345134  20-08-31
# 21     AAPL   108.0   109.0  308151392  20-08-03
# 22     AAPL   109.0   110.0  172792368  20-08-04
# 23     AAPL   109.0   110.0  121991952  20-08-05
# 24     AAPL   110.0   114.0  202428896  20-08-06
# 25     AAPL   113.0   111.0  198045616  20-08-07
# 26     AAPL   113.0   113.0  212403424  20-08-10
# 27     AAPL   112.0   109.0  187902368  20-08-11
# 28     AAPL   110.0   113.0  165944816  20-08-12
# 29     AAPL   114.0   115.0  210082064  20-08-13
# ..      ...     ...     ...        ...       ...
# 75     NFLX   494.0   485.0    3156218  20-08-19
# 76     NFLX   485.0   498.0    5132480  20-08-20
# 77     NFLX   496.0   492.0    3921293  20-08-21
# 78     NFLX   495.0   489.0    4762183  20-08-24
# 79     NFLX   488.0   491.0    5727721  20-08-25
# 80     NFLX   493.0   548.0   20373680  20-08-26
# 81     NFLX   538.0   526.0    9062912  20-08-27
# 82     NFLX   532.0   524.0    4417517  20-08-28
# 83     NFLX   521.0   530.0    4941409  20-08-31
# 84     GOOG  1487.0  1474.0    4660400  20-08-03
# 85     GOOG  1477.0  1465.0    1903500  20-08-04
# 86     GOOG  1469.0  1474.0    1979500  20-08-05
# 87     GOOG  1472.0  1500.0    1995400  20-08-06
# 88     GOOG  1500.0  1494.0    1576600  20-08-07
# 89     GOOG  1487.0  1496.0    1289300  20-08-10
# 90     GOOG  1492.0  1480.0    1454400  20-08-11
# 91     GOOG  1486.0  1507.0    1437700  20-08-12
# 92     GOOG  1510.0  1518.0    1455200  20-08-13
# 93     GOOG  1516.0  1508.0    1354800  20-08-14
# 94     GOOG  1515.0  1518.0    1378300  20-08-17
# 95     GOOG  1526.0  1559.0    2027100  20-08-18
# 96     GOOG  1553.0  1548.0    1660600  20-08-19
# 97     GOOG  1543.0  1582.0    1706900  20-08-20
# 98     GOOG  1577.0  1580.0    1446500  20-08-21
# 99     GOOG  1594.0  1588.0    2819800  20-08-24
# 100    GOOG  1582.0  1608.0    2247100  20-08-25
# 101    GOOG  1608.0  1652.0    3993400  20-08-26
# 102    GOOG  1654.0  1634.0    1861600  20-08-27
# 103    GOOG  1633.0  1644.0    1499800  20-08-28
# 104    GOOG  1648.0  1634.0    3646806  20-08-31
#
# [105 rows x 5 columns]

# %%
stock_quotes.to_csv('stock_quotes.csv')
