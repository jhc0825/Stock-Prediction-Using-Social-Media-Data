# %%
import tweepy
import pandas as pd

# %%
# Variables that contains the credentials to access Twitter API
ACCESS_TOKEN = '989875549-WIXvU04wB8NjpeWTzsWahfxHmOnUoA3Kl0ISUlfN'
ACCESS_SECRET = '4RWG0hiYNoWTczNHwErw6xMvBbjbSpIpWkVjThDVfEeRo'
CONSUMER_KEY = 'p4dL1DlwWrEDKpi3NyAuVSZ1c'
CONSUMER_SECRET = 'YmcryArWJY65urO103AXOCNoKpNcFEzHvuuiIT40XXO5QMeOLw'


# Setup access to API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    api = tweepy.API(auth)
    return api


# Create API object
api = connect_to_twitter_OAuth()

# %%
from twython import Twython
import json

python_tweets = Twython(CONSUMER_KEY, CONSUMER_SECRET)

query = {'q': 'amazon',
        'result_type': 'recent',
        'count': 100,
        'lang': 'en',
        }

# %%
import pandas as pd

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'likes': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['likes'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
amazon = pd.DataFrame(dict_)
amazon.sort_values(by='likes', inplace=True, ascending=False)
amazon['company'] = 'Amazon'

# %%
query = {'q': 'facebook',
        'result_type': 'recent',
        'count': 100,
        'lang': 'en',
        }
# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'likes': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['likes'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
facebook = pd.DataFrame(dict_)
facebook.sort_values(by='likes', inplace=True, ascending=False)
facebook['company'] = "Facebook"

# %%
query = {'q': 'apple',
        'result_type': 'recent',
        'count': 100,
        'lang': 'en',
        }
# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'likes': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['likes'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
apple = pd.DataFrame(dict_)
apple.sort_values(by='likes', inplace=True, ascending=False)
apple['company'] = "Apple"

# %%
query = {'q': 'netflix',
        'result_type': 'recent',
        'count': 100,
        'lang': 'en',
        }
# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'likes': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['likes'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
netflix = pd.DataFrame(dict_)
netflix.sort_values(by='likes', inplace=True, ascending=False)
netflix['company'] = "Netflix"

# %%
query = {'q': 'google',
        'result_type': 'recent',
        'count': 100,
        'lang': 'en',
        }
# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'likes': []}
for status in python_tweets.search(**query)['statuses']:
    dict_['user'].append(status['user']['screen_name'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['likes'].append(status['favorite_count'])

# Structure data in a pandas DataFrame for easier manipulation
google = pd.DataFrame(dict_)
google.sort_values(by='likes', inplace=True, ascending=False)
google['company'] = "Google"

# %%
FAANG = [facebook, apple, amazon, netflix, google]
faang_df = pd.concat(FAANG)
faang_df = faang_df.reset_index(drop = True)
faang_df
# Out:
#                 user                            date  \
# 0           Magic899  Mon Oct 26 00:15:42 +0000 2020
# 1      SheRa_Resists  Mon Oct 26 00:15:56 +0000 2020
# 2       FoustRebecca  Mon Oct 26 00:15:26 +0000 2020
# 3       sikandar1786  Mon Oct 26 00:15:21 +0000 2020
# 4       Nuha47488115  Mon Oct 26 00:15:22 +0000 2020
# ..               ...                             ...
# 489  SCJ_morganburke  Mon Oct 26 00:15:46 +0000 2020
# 490       ggukvision  Mon Oct 26 00:15:46 +0000 2020
# 491           vvei_k  Mon Oct 26 00:15:46 +0000 2020
# 492     DanGarrett97  Mon Oct 26 00:15:46 +0000 2020
# 493      Kcimarrones  Mon Oct 26 00:15:18 +0000 2020
#
#                                                   text  likes   company
# 0    Few more days ‘til a new month! 🥳 Let’s have a...      1  Facebook
# 1    RT @WorkingFamilies: Next up on our GOTV rally...      0  Facebook
# 2    RT @LSevick: Looking forward to reading with m...      0  Facebook
# ...

# %%
faang_df.columns
# Out:
# Index(['user', 'date', 'text', 'likes', 'company'], dtype='object')
